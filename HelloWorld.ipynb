# %%
# %reset -f
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from VentiModel import *

lung = VentiModel()

# lung.Flowin_constant()
# lung.Inspiration()
# lung.Hold()
# lung.Expiration()
df = lung.Breath(4)  # number of breaths

fig, ax = plt.subplots(3,1, figsize=(10,8), sharex=True)
df['Paw'].plot(ax=ax[2])
df['Vt'].plot(ax=ax[1])
df['Faw'].plot(ax=ax[0])

ax[0].grid();ax[1].grid();ax[2].grid();
ax[0].set_title('Flow (L/s)');
ax[1].set_title('Delivered Tidal Volume (L)');
ax[2].set_title('Airway Pressure (cm_H2O)');
ax[2].set_xlabel('Time (s)');
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
print('Breath per Minutes:', lung.BPM)
print('PEEP (cm_H2O):', lung.P_peep)
print('IE :', lung.IE)
print('Tidal Volume (L):', lung.Vt)

lung = VentiModel(BPM=10, R = 15, VCon=0.5/100, P_peep=5)

T, T_inhale, T_hold, T_exhale = lung.RespTime()
print(f'Breath Time: {T}s, Inhale: {T_inhale}s, Hold: {T_hold}s, Exhale: {T_exhale}s')

df.head()

df = lung.Breath(3)

fig, ax = plt.subplots(3,1, figsize=(8,8), sharex=True)
df['Paw'].plot(ax=ax[2])
df['Vt'].plot(ax=ax[1])
df['Faw'].plot(ax=ax[0])

ax[0].grid();ax[1].grid();ax[2].grid();
ax[0].set_title('Flow (L/s)');
ax[1].set_title('Delivered Tidal Volume (L)');
ax[2].set_title('Airway Pressure (cm_H2O)');
ax[2].set_xlabel('Time (s)');
# Out:
# Breath per Minutes: 10
# PEEP (cm_H2O): 5
# IE : 3.3
# Tidal Volume (L): 0.5
# Breath Time: 6.0s, Inhale: 1.256s, Hold: 0.14s, Exhale: 4.605s
# <img src="data:image/png;base64,..." width="800">
